# %% [markdown]
# # Live Coding 3D Face Analysis with InsightFace

# %%
# !pip install numpy
# Out:
# Requirement already satisfied: numpy in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (1.26.4)

# %%
# !pip install insightface
# Out:
# Collecting insightface
#   Downloading insightface-0.7.3.tar.gz (439 kB)
#      ---------------------------------------- 0.0/439.5 kB ? eta -:--:--
#      -- ------------------------------------- 30.7/439.5 kB ? eta -:--:--
#      ------ -------------------------------- 71.7/439.5 kB 1.3 MB/s eta 0:00:01
#      ---------------- --------------------- 194.6/439.5 kB 1.3 MB/s eta 0:00:01
#      ---------------- --------------------- 194.6/439.5 kB 1.3 MB/s eta 0:00:01
#      ---------------- --------------------- 194.6/439.5 kB 1.3 MB/s eta 0:00:01
#      ----------------------- ------------ 286.7/439.5 kB 883.3 kB/s eta 0:00:01
#      ----------------------- ------------ 286.7/439.5 kB 883.3 kB/s eta 0:00:01
#      ----------------------- ------------ 286.7/439.5 kB 883.3 kB/s eta 0:00:01
#      ----------------------- ------------ 286.7/439.5 kB 883.3 kB/s eta 0:00:01
#      ----------------------- ------------ 286.7/439.5 kB 883.3 kB/s eta 0:00:01
#      -------------------------------- --- 399.4/439.5 kB 691.2 kB/s eta 0:00:01
#      ------------------------------------ 439.5/439.5 kB 669.7 kB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: numpy in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from insightface) (1.23.0)
# Collecting onnx (from insightface)
#   Downloading onnx-1.15.0-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: tqdm in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from insightface) (4.64.0)
# Requirement already satisfied: requests in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from insightface) (2.28.1)
# Requirement already satisfied: matplotlib in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from insightface) (3.5.2)
# Requirement already satisfied: Pillow in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from insightface) (9.2.0)
# Requirement already satisfied: scipy in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from insightface) (1.8.1)
# Collecting scikit-learn (from insightface)
#   Downloading scikit_learn-1.4.1.post1-cp39-cp39-win_amd64.whl.metadata (11 kB)
# Collecting scikit-image (from insightface)
#   Downloading scikit_image-0.22.0-cp39-cp39-win_amd64.whl.metadata (13 kB)
# Collecting easydict (from insightface)
#   Using cached easydict-1.12-py3-none-any.whl.metadata (4.1 kB)
# Collecting cython (from insightface)
#   Using cached Cython-3.0.8-cp39-cp39-win_amd64.whl.metadata (3.2 kB)
# Collecting albumentations (from insightface)
#   Downloading albumentations-1.4.0-py3-none-any.whl.metadata (35 kB)
# Collecting prettytable (from insightface)
#   Downloading prettytable-3.10.0-py3-none-any.whl.metadata (30 kB)
# Collecting numpy (from insightface)
#   Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl.metadata (61 kB)
# Collecting scipy (from insightface)
#   Using cached scipy-1.12.0-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: PyYAML in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from albumentations->insightface) (6.0)
# Collecting qudida>=0.0.4 (from albumentations->insightface)
#   Downloading qudida-0.0.4-py3-none-any.whl (3.5 kB)
# Collecting opencv-python>=4.9.0 (from albumentations->insightface)
#   Downloading opencv_python-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: networkx>=2.8 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from scikit-image->insightface) (3.2.1)
# Collecting imageio>=2.27 (from scikit-image->insightface)
#   Downloading imageio-2.34.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->insightface)
#   Downloading tifffile-2024.2.12-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from scikit-image->insightface) (23.2)
# Collecting lazy_loader>=0.3 (from scikit-image->insightface)
#   Downloading lazy_loader-0.3-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->insightface) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->insightface) (4.34.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->insightface) (1.4.3)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->insightface) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from matplotlib->insightface) (2.8.2)
# Requirement already satisfied: protobuf>=3.20.2 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from onnx->insightface) (4.25.3)
# Requirement already satisfied: wcwidth in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from prettytable->insightface) (0.2.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from requests->insightface) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from requests->insightface) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from requests->insightface) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from requests->insightface) (2022.6.15)
# Collecting joblib>=1.2.0 (from scikit-learn->insightface)
#   Downloading joblib-1.3.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=2.0.0 (from scikit-learn->insightface)
#   Downloading threadpoolctl-3.3.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: colorama in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from tqdm->insightface) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from python-dateutil>=2.7->matplotlib->insightface) (1.16.0)
# Requirement already satisfied: typing-extensions in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from qudida>=0.0.4->albumentations->insightface) (4.9.0)
# Collecting opencv-python-headless>=4.0.1 (from qudida>=0.0.4->albumentations->insightface)
#   Downloading opencv_python_headless-4.9.0.80-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Downloading albumentations-1.4.0-py3-none-any.whl (123 kB)
#    ---------------------------------------- 0.0/123.6 kB ? eta -:--:--
#    ----------------------- ---------------- 71.7/123.6 kB 2.0 MB/s eta 0:00:01
#    ---------------------------------------- 123.6/123.6 kB 1.5 MB/s eta 0:00:00
# Using cached numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
# Downloading scikit_image-0.22.0-cp39-cp39-win_amd64.whl (24.5 MB)
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/24.5 MB 1.7 MB/s eta 0:00:15
#    ---------------------------------------- 0.2/24.5 MB 1.5 MB/s eta 0:00:16
#    ---------------------------------------- 0.2/24.5 MB 1.7 MB/s eta 0:00:15
#     --------------------------------------- 0.3/24.5 MB 1.8 MB/s eta 0:00:14
#     --------------------------------------- 0.4/24.5 MB 1.9 MB/s eta 0:00:13
#     --------------------------------------- 0.5/24.5 MB 1.9 MB/s eta 0:00:13
#    - -------------------------------------- 0.6/24.5 MB 2.0 MB/s eta 0:00:13
#    - -------------------------------------- 0.8/24.5 MB 2.0 MB/s eta 0:00:12
#    - -------------------------------------- 0.8/24.5 MB 2.0 MB/s eta 0:00:12
#    - -------------------------------------- 1.0/24.5 MB 2.1 MB/s eta 0:00:12
#    - -------------------------------------- 1.1/24.5 MB 2.2 MB/s eta 0:00:11
#    - -------------------------------------- 1.2/24.5 MB 2.2 MB/s eta 0:00:11
#    -- ------------------------------------- 1.4/24.5 MB 2.3 MB/s eta 0:00:11
#    -- ------------------------------------- 1.5/24.5 MB 2.4 MB/s eta 0:00:10
#    -- ------------------------------------- 1.8/24.5 MB 2.5 MB/s eta 0:00:10
#    --- ------------------------------------ 2.0/24.5 MB 2.6 MB/s eta 0:00:09
#    --- ------------------------------------ 2.2/24.5 MB 2.7 MB/s eta 0:00:09
#    --- ------------------------------------ 2.4/24.5 MB 2.8 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.7/24.5 MB 2.9 MB/s eta 0:00:08
#    ---- ----------------------------------- 2.9/24.5 MB 3.0 MB/s eta 0:00:08
#    ----- ---------------------------------- 3.1/24.5 MB 3.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.3/24.5 MB 3.2 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.6/24.5 MB 3.3 MB/s eta 0:00:07
#    ------ --------------------------------- 3.9/24.5 MB 3.4 MB/s eta 0:00:07
#    ------ --------------------------------- 4.3/24.5 MB 3.5 MB/s eta 0:00:06
#    ------- -------------------------------- 4.6/24.5 MB 3.7 MB/s eta 0:00:06
#    -------- ------------------------------- 5.0/24.5 MB 3.8 MB/s eta 0:00:06
#    -------- ------------------------------- 5.3/24.5 MB 3.9 MB/s eta 0:00:05
#    --------- ------------------------------ 5.6/24.5 MB 4.0 MB/s eta 0:00:05
#    --------- ------------------------------ 6.1/24.5 MB 4.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 6.5/24.5 MB 4.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 6.8/24.5 MB 4.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 7.2/24.5 MB 4.5 MB/s eta 0:00:04
#    ------------ --------------------------- 7.7/24.5 MB 4.7 MB/s eta 0:00:04
#    ------------- -------------------------- 8.0/24.5 MB 4.7 MB/s eta 0:00:04
#    -------------- ------------------------- 8.7/24.5 MB 5.0 MB/s eta 0:00:04
#    -------------- ------------------------- 9.2/24.5 MB 5.1 MB/s eta 0:00:03
#    --------------- ------------------------ 9.6/24.5 MB 5.3 MB/s eta 0:00:03
#    ---------------- ----------------------- 10.2/24.5 MB 5.4 MB/s eta 0:00:03
#    ----------------- ---------------------- 10.9/24.5 MB 6.4 MB/s eta 0:00:03
#    ------------------ --------------------- 11.5/24.5 MB 7.3 MB/s eta 0:00:02
#    ------------------- -------------------- 12.0/24.5 MB 7.9 MB/s eta 0:00:02
#    -------------------- ------------------- 12.8/24.5 MB 8.7 MB/s eta 0:00:02
#    ---------------------- ----------------- 13.5/24.5 MB 9.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 14.6/24.5 MB 10.7 MB/s eta 0:00:01
#    ------------------------ --------------- 15.3/24.5 MB 11.3 MB/s eta 0:00:01
#    -------------------------- ------------- 16.0/24.5 MB 12.1 MB/s eta 0:00:01
#    --------------------------- ------------ 16.9/24.5 MB 13.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 18.0/24.5 MB 14.2 MB/s eta 0:00:01
#    ------------------------------ --------- 18.7/24.5 MB 15.2 MB/s eta 0:00:01
#    -------------------------------- ------- 19.7/24.5 MB 15.6 MB/s eta 0:00:01
#    --------------------------------- ------ 20.3/24
8 MB/s eta 0:00:02
#    ---------- ----------------------------- 10.5/38.5 MB 16.4 MB/s eta 0:00:02
#    ------------ --------------------------- 11.6/38.5 MB 16.4 MB/s eta 0:00:02
#    ------------ --------------------------- 11.8/38.5 MB 15.2 MB/s eta 0:00:02
#    ------------- -------------------------- 12.9/38.5 MB 15.2 MB/s eta 0:00:02
#    ------------- -------------------------- 13.3/38.5 MB 14.9 MB/s eta 0:00:02
#    -------------- ------------------------- 14.0/38.5 MB 13.9 MB/s eta 0:00:02
#    --------------- ------------------------ 14.7/38.5 MB 14.2 MB/s eta 0:00:02
#    --------------- ------------------------ 14.9/38.5 MB 13.9 MB/s eta 0:00:02
#    ---------------- ----------------------- 15.9/38.5 MB 13.6 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.4/38.5 MB 13.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 17.1/38.5 MB 13.6 MB/s eta 0:00:02
#    ------------------ --------------------- 17.6/38.5 MB 12.8 MB/s eta 0:00:02
#    ------------------ --------------------- 18.2/38.5 MB 13.4 MB/s eta 0:00:02
#    ------------------- -------------------- 19.2/38.5 MB 13.1 MB/s eta 0:00:02
#    -------------------- ------------------- 19.7/38.5 MB 13.4 MB/s eta 0:00:02
#    --------------------- ------------------ 20.3/38.5 MB 13.6 MB/s eta 0:00:02
#    --------------------- ------------------ 21.1/38.5 MB 13.9 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.6/38.5 MB 13.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.9/38.5 MB 13.4 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.0/38.5 MB 13.4 MB/s eta 0:00:02
#    ------------------------ --------------- 23.5/38.5 MB 13.4 MB/s eta 0:00:02
#    ------------------------- -------------- 24.2/38.5 MB 14.2 MB/s eta 0:00:02
#    ------------------------- -------------- 25.0/38.5 MB 13.6 MB/s eta 0:00:01
#    -------------------------- ------------- 25.6/38.5 MB 14.2 MB/s eta 0:00:01
#    --------------------------- ------------ 26.1/38.5 MB 13.4 MB/s eta 0:00:01
#    --------------------------- ------------ 26.8/38.5 MB 14.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 27.4/38.5 MB 13.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.1/38.5 MB 14.2 MB/s eta 0:00:01
#    ----------------------------- ---------- 28.7/38.5 MB 14.2 MB/s eta 0:00:01
#    ------------------------------ --------- 29.4/38.5 MB 13.4 MB/s eta 0:00:01
#    ------------------------------- -------- 29.9/38.5 MB 14.2 MB/s eta 0:00:01
#    ------------------------------- -------- 30.6/38.5 MB 13.9 MB/s eta 0:00:01
#    -------------------------------- ------- 31.3/38.5 MB 13.6 MB/s eta 0:00:01
#    -------------------------------- ------- 31.8/38.5 MB 13.4 MB/s eta 0:00:01
#    --------------------------------- ------ 32.5/38.5 MB 13.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.2/38.5 MB 13.6 MB/s eta 0:00:01
#    ----------------------------------- ---- 34.0/38.5 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------ --- 34.7/38.5 MB 13.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.6/38.5 MB 14.2 MB/s eta 0:00:01
#    ------------------------------------- -- 36.4/38.5 MB 14.6 MB/s eta 0:00:01
#    -------------------------------------- - 37.2/38.5 MB 15.2 MB/s eta 0:00:01
#    ---------------------------------------  38.2/38.5 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------  38.5/38.5 MB 15.6 MB/s eta 0:00:01
#    ---------------------------------------- 38.5/38.5 MB 8.8 MB/s eta 0:00:00
# Building wheels for collected packages: insightface
#   Building wheel for insightface (pyproject.toml): started
#   Building wheel for insightface (pyproject.toml): finished with status 'done'
#   Created wheel for insightface: filename=insightface-0.7.3-cp39-cp39-win_amd64.whl size=871175 sha256=09d9baacf9f4499488d50fb157f190cfdbec6fda88f7173a9747f81844a13151
#   Stored in directory: c:\users\vaidehi enterprise\appdata\local\pip\cache\wheels\36\d1\8d\4994a23418af46d1edf9eb83d16c08c68314b79d9074b5d30a
# Successfully built insightface
# Installing collected packages: easydict, threadpoolctl, prettytable, numpy, lazy_loader, joblib, cython, tifffile, scipy, opencv-python-headless, opencv-python, onnx, imageio, scikit-learn, scikit-image, qudida, albumentations, insightface
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.23.0
#     Uninstalling numpy-1.23.0:
#       Successfully uninstalled numpy-1.23.0
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.8.1
#     Uninstalling scipy-1.8.1:
#       Successfully uninstalled scipy-1.8.1
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.6.0.66
#     Uninstalling opencv-python-4.6.0.66:
#       Successfully uninstalled opencv-python-4.6.0.66
# Successfully installed albumentations-1.4.0 cython-3.0.8 easydict-1.12 imageio-2.34.0 insightface-0.7.3 joblib-1.3.2 lazy_loader-0.3 numpy-1.26.4 onnx-1.15.0 opencv-python-4.9.0.80 opencv-python-headless-4.9.0.80 prettytable-3.10.0 qudida-0.0.4 scikit-image-0.22.0 scikit-learn-1.4.1.post1 scipy-1.12.0 threadpoolctl-3.3.0 tifffile-2024.2.12
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorboard 2.9.1 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.25.3 which is incompatible.

# %%
# !pip install onnxruntime
# Out:
# Collecting onnxruntime
#   Downloading onnxruntime-1.17.0-cp39-cp39-win_amd64.whl.metadata (4.3 kB)
# Collecting coloredlogs (from onnxruntime)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/46.0 kB ? eta -:--:--
#      ---------------------------------------- 46.0/46.0 kB 2.2 MB/s eta 0:00:00
# Collecting flatbuffers (from onnxruntime)
#   Downloading flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: numpy>=1.21.6 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from onnxruntime) (1.26.4)
# Requirement already satisfied: packaging in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from onnxruntime) (23.2)
# Requirement already satisfied: protobuf in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from onnxruntime) (4.25.3)
# Requirement already satisfied: sympy in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from onnxruntime) (1.12)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 0.0/86.8 kB ? eta -:--:--
#      ---------------------------------------- 86.8/86.8 kB 4.8 MB/s eta 0:00:00
# Requirement already satisfied: mpmath>=0.19 in c:\users\vaidehi enterprise\appdata\local\programs\python\python39\lib\site-packages (from sympy->onnxruntime) (1.3.0)
# Collecting pyreadline3 (from humanfriendly>=9.1->coloredlogs->onnxruntime)
#   Downloading pyreadline3-3.4.1-py3-none-any.whl (95 kB)
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 0.0/95.2 kB ? eta -:--:--
#      ---------------------------------------- 95.2/95.2 kB 5.3 MB/s eta 0:00:00
# Downloading onnxruntime-1.17.0-cp39-cp39-win_amd64.whl (5.6 MB)
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#    ---------------------------------------- 0.0/5.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.6 MB ? eta -:--:--
#     --------------------------------------- 0.1/5.6 MB 313.8 kB/s eta 0:00:18
#    - -------------------------------------- 0.1/5.6 MB 303.9 kB/s eta 0:00:18
#    - -------------------------------------- 0.1/5.6 MB 303.9 kB/s eta 0:00:18
#    - -------------------------------------- 0.1/5.6 MB 303.9 kB/s eta 0:00:18
#    - -------------------------------------- 0.1/5.6 MB 303.9 kB/s eta 0:00:18
#    - -------------------------------------- 0.1/5.6 MB 303.9 kB/s eta 0:00:18
#    - -------------------------------------- 0.1/5.6 MB 303.9 kB/s eta 0:00:18
#    - -------------------------------------- 0.2/5.6 MB 244.1 kB/s eta 0:00:23
#    - -------------------------------------- 0.2/5.6 MB 269.2 kB/s eta 0:00:20
#    -- ------------------------------------- 0.4/5.6 MB 388.7 kB/s eta 0:00:14
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.6/5.6 MB 581.2 kB/s eta 0:00:09
#    ---- ----------------------------------- 0.7/5.6 MB 460.9 kB/s eta 0:00:11
#    ----- ---------------------------------- 0.8/5.6 MB 499.8 kB/s eta 0:00:10
#    ------- -------------------------------- 1.0/5.6 MB 635.9 kB/s eta 0:00:08
#    --------- ------------------------------ 1.3/5.6 MB 768.8 kB/s eta 0:00:06
#    ---------- ----------------------------- 1.5/5.6 MB 909.0 kB/s eta 0:00:05
#    ------------- -------------------------- 1.8/5.6 MB 1.1 MB/s eta 0:00:04
#    --------------- ------------------------ 2.2/5.6 MB 1.2 MB/s eta 0:00:03
#    ----------------- ---------------------- 2.4/5.6 MB 1.3 MB/s eta 0:00:03
#    ------------------- -------------------- 2.8/5.6 MB 1.5 MB/s eta 0:00:02
#    --------------------- ------------------ 3.1/5.6 MB 1.6 MB/s eta 0:00:02
#    ------------------------ --------------- 3.4/5.6 MB 1.7 MB/s eta 0:00:02
#    -------------------------- ------------- 3.7/5.6 MB 1.8 MB/s eta 0:00:02
#    ---------------------------- ----------- 4.0/5.6 MB 2.0 MB/s eta 0:00:01
#    ------------------------------- -------- 4.4/5.6 MB 2.1 MB/s eta 0:00:01
#    --------------------------------- ------ 4.7/5.6 MB 2.2 MB/s eta 0:00:01
#    ------------------------------------ --- 5.0/5.6 MB 2.3 MB/s eta 0:00:01
#    -------------------------------------- - 5.4/5.6 MB 2.4 MB/s eta 0:00:01
#    ---------------------------------------  5.6/5.6 MB 2.5 MB/s eta 0:00:01
#    ---------------------------------------- 5.6/5.6 MB 2.4 MB/s eta 0:00:00
# Downloading flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Installing collected packages: pyreadline3, flatbuffers, humanfriendly, coloredlogs, onnxruntime
# Successfully installed coloredlogs-15.0.1 flatbuffers-23.5.26 humanfriendly-10.0 onnxruntime-1.17.0 pyreadline3-3.4.1

# %%
import datetime
import numpy as np
import os
import os.path as osp
import glob
import cv2
import insightface
from insightface.app import FaceAnalysis
from insightface.data import get_image as ins_get_image
import matplotlib.pyplot as plt

# %%
print('insightface', insightface.__version__)
print('numpy', np.__version__)
# Out:
# insightface 0.7.3
# numpy 1.26.4

# %%
assert float('.'.join(insightface.__version__.split('.')[:2]))>=float('0.7')

# %%
app = FaceAnalysis(name='buffalo_l')
app.prepare(ctx_id=0, det_size=(640, 640))
# Out:
# c:\Users\VAIDEHI ENTERPRISE\AppData\Local\Programs\Python\Python39\lib\site-packages\onnxruntime\capi\onnxruntime_inference_collection.py:69: UserWarning: Specified provider 'CUDAExecutionProvider' is not in available provider names.Available providers: 'AzureExecutionProvider, CPUExecutionProvider'
#   warnings.warn(
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\VAIDEHI ENTERPRISE/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\VAIDEHI ENTERPRISE/.insightface\models\buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\VAIDEHI ENTERPRISE/.insightface\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\VAIDEHI ENTERPRISE/.insightface\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\VAIDEHI ENTERPRISE/.insightface\models\buffalo_l\w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (640, 640)

# %%
# !pip

# %%
swapper = insightface.model_zoo.get_model('inswapper_128.onnx',
                                download=False,
                                download_zip=False)
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# inswapper-shape: [1, 3, 128, 128]

# %%
img = ins_get_image('t1')
plt.imshow(img[:,:,::-1])
plt.show()

# %% [markdown]
# # Detecting the Faces
# - Using buffalo_l model

# %%
# Detected faces
faces = app.get(img)
# Out:
# c:\Users\VAIDEHI ENTERPRISE\AppData\Local\Programs\Python\Python39\lib\site-packages\insightface\utils\transform.py:68: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   P = np.linalg.lstsq(X_homo, Y)[0].T # Affine matrix. 3 x 4

# %%
img = ins_get_image('t1')
fig, axs = plt.subplots(1, 6, figsize=(12, 5))

for i, face in enumerate(faces):
    bbox = face['bbox']
    bbox = [int(b) for b in bbox]
    axs[i].imshow(img[bbox[1]:bbox[3],bbox[0]:bbox[2],::-1])
    axs[i].axis('off')

# %% [markdown]
# # Face Swapping Time!

# %%
# Sorts left to right
faces = sorted(faces, key = lambda x : x.bbox[0])
res = img.copy()
assert len(faces)==6 # Confirm 6 faces found
source_face = faces[2]

# %%
bbox = source_face['bbox']
bbox = [int(b) for b in bbox]
plt.imshow(img[bbox[1]:bbox[3],bbox[0]:bbox[2],::-1])
plt.show()

# %%
for face in faces:
    res = swapper.get(res, face, source_face, paste_back=True)

# %% [markdown]
# # After "swapper.get"

# %%
plt.imshow(res[:,:,::-1])
plt.show()

# %%
res = []
for face in faces:
    _img, _ = swapper.get(img, face, source_face, paste_back=False)
    res.append(_img)
res = np.concatenate(res, axis=1)

plt.imshow(res[:,:,::-1])
plt.show()

# %% [markdown]
# # Put My Face on it

# %%
rob = cv2.imread('C:/Users/VAIDEHI ENTERPRISE/Pictures/Camera Roll/test.jpg')

# %%
import matplotlib.pyplot as plt

plt.imshow(rob[:,:,::-1])
plt.show()

# %% [markdown]
# ## 1. Detect and Save my Face

# %%
rob_faces = app.get(rob)
assert len(rob_faces) == 1
rob_face = rob_faces[0]
bbox = rob_face['bbox']
bbox = [int(b) for b in bbox]
plt.imshow(rob[bbox[1]:bbox[3],bbox[0]:bbox[2],::-1])
plt.show()

# %% [markdown]
# ## 2. Detect Friend's faces

# %%
faces = app.get(img)

# %% [markdown]
# ## 3. Swap my face for theirs on the image

# %%
res = img.copy()
for face in faces:
    res = swapper.get(res, face, rob_face, paste_back=True)
plt.imshow(res[:,:,::-1])
plt.show()

# %% [markdown]
# ## Close up view!

# %%
res = []
for face in faces:
    _img, _ = swapper.get(img,
                          face,
                          rob_face,
                          paste_back=False)
    res.append(_img)
res = np.concatenate(res, axis=1)

plt.imshow(res[:,:,::-1])
plt.show()

# %% [markdown]
# ## Swap with Monty Python

# %%
monty = cv2.imread('C:/Users/VAIDEHI ENTERPRISE/Pictures/jnd/test3.jpg')
plt.imshow(monty[:,:,::-1])
plt.show()

# %%
faces = app.get(monty)

# %%
fig, axs = plt.subplots(1, 9, figsize=(12, 5))

for i, face in enumerate(faces):
    bbox = face['bbox']
    bbox = [int(b) for b in bbox]
    axs[i].imshow(monty[bbox[1]:bbox[3],bbox[0]:bbox[2],::-1])
    axs[i].axis('off')

# %%
faces = app.get(monty)
res = monty.copy()
for face in faces:
    res = swapper.get(res, face, rob_face, paste_back=True)
plt.imshow(res[:,:,::-1])
plt.show()

# %% [markdown]
# # Swap two faces

# %%
img1 = cv2.imread('C:/Users/VAIDEHI ENTERPRISE/Pictures/Camera Roll/test.jpg')
img2 = cv2.imread('C:/Users/VAIDEHI ENTERPRISE/Pictures/Camera Roll/test5.jpg')

fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(img1[:,:,::-1])
axs[0].axis('off')
axs[1].imshow(img2[:,:,::-1])
axs[1].axis('off')
plt.show()

# %%
face1 = app.get(img1)[0]
face2 = app.get(img2)[0]

# %%
img1_ = img1.copy()
img2_ = img2.copy()
img1_ = swapper.get(img1_, face1, face2, paste_back=True)
img2_ = swapper.get(img2_, face2, face1, paste_back=True)
fig, axs = plt.subplots(1, 2, figsize=(10, 5))
axs[0].imshow(img1_[:,:,::-1])
axs[0].axis('off')
axs[1].imshow(img2_[:,:,::-1])
axs[1].axis('off')
plt.show()

# %%
def swap_n_show(img1_fn, img2_fn, app, swapper,
                plot_before=True, plot_after=True):
    """
    Uses face swapper to swap faces in two different images.
    
    plot_before: if True shows the images before the swap
    plot_after: if True shows the images after the swap
    
    returns images with swapped faces.
    
    Assumes one face per image.
    """
    img1 = cv2.imread(img1_fn)
    img2 = cv2.imread(img2_fn)
    
    if plot_before:
        fig, axs = plt.subplots(1, 2, figsize=(10, 5))
        axs[0].imshow(img1[:,:,::-1])
        axs[0].axis('off')
        axs[1].imshow(img2[:,:,::-1])
        axs[1].axis('off')
        plt.show()
    
    # Do the swap
    face1 = app.get(img1)[0]
    face2 = app.get(img2)[0]
    
    img1_ = img1.copy()
    img2_ = img2.copy()
    if plot_after:
        img1_ = swapper.get(img1_, face1, face2, paste_back=True)
        img2_ = swapper.get(img2_, face2, face1, paste_back=True)
        fig, axs = plt.subplots(1, 2, figsize=(10, 5))
        axs[0].imshow(img1_[:,:,::-1])
        axs[0].axis('off')
        axs[1].imshow(img2_[:,:,::-1])
        axs[1].axis('off')
        plt.show()
    return img1_, img2_

# %%
_ = swap_n_show('C:/Users/VAIDEHI ENTERPRISE/Pictures/Phone/V V P/jinlu/test6.jpg', 'C:/Users/VAIDEHI ENTERPRISE/Pictures/Phone/V V P/jinlu/test7.jpg', app, swapper)

# %% [markdown]
# # Swap Faces try again

# %%
def swap_n_show_same_img(img1_fn,
                         app, swapper,
                         plot_before=True,
                         plot_after=True):
    """
    Uses face swapper to swap faces in the same image.
    
    plot_before: if True shows the images before the swap
    plot_after: if True shows the images after the swap
    
    returns images with swapped faces.
    
    Assumes one face per image.
    """
    img1 = cv2.imread(img1_fn)
    
    if plot_before:
        fig, ax = plt.subplots(1, 1, figsize=(10, 5))
        ax.imshow(img1[:,:,::-1])
        ax.axis('off')
        plt.show()
    
    # Do the swap
    faces = app.get(img1)
    face1, face2 = faces[0], faces[1]
    
    img1_ = img1.copy()
    if plot_after:
        img1_ = swapper.get(img1_, face1, face2, paste_back=True)
        img1_ = swapper.get(img1_, face2, face1, paste_back=True)
        fig, ax = plt.subplots(1, 1, figsize=(10, 5))
        ax.imshow(img1_[:,:,::-1])
        ax.axis('off')
        plt.show()
    return img1_

# %%
_ = swap_n_show_same_img('C:/Users/VAIDEHI ENTERPRISE/Pictures/jnd/kk.jpg', app, swapper)

# %% [markdown]
# # Test on Animal

# %%
cow = cv2.imread('C:/Users/VAIDEHI ENTERPRISE/Pictures/Saved Pictures/horse.jpg')
plt.imshow(cow[:,:,::-1])
plt.show()

# %%
app.get(cow)
# Out:
# []

# %% [markdown]
# # Swap Faces of Celebrity Couples

# %%
from glob import glob
couples = glob('couple*')

# %%
for couple in couples:
    _ = swap_n_show_same_img(couple, app, swapper)
